# %%
from wwo_hist import retrieve_hist_data

# %%
import os
os.chdir("/root/Documents/")

# %%
frequency=1
start_date = '1-JAN-2015'
end_date = '25-JUN-2022'
api_key = 'fedd6b5919fb4be6bd011230222506'
location_list = ['India']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for India
#
#
# Currently retrieving data for India: from 2015-01-01 to 2015-01-31
# /root/anaconda3/lib/python3.9/site-packages/wwo_hist/__init__.py:69: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# /root/anaconda3/lib/python3.9/site-packages/wwo_hist/__init__.py:74: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:02.225672
# Currently retrieving data for India: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:03.912939
# Currently retrieving data for India: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.757758
# Currently retrieving data for India: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.396296
# Currently retrieving data for India: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.283819
# Currently retrieving data for India: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.942030
# Currently retrieving data for India: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.345628
# Currently retrieving data for India: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.017671
# Currently retrieving data for India: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:16.506893
# Currently retrieving data for India: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:18.455252
# Currently retrieving data for India: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:20.461424
# Currently retrieving data for India: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.338720
# Currently retrieving data for India: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.458515
# Currently retrieving data for India: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:26.065918
# Currently retrieving data for India: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.504330
# Currently retrieving data for India: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:28.831886
# Currently retrieving data for India: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.662657
# Currently retrieving data for India: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:31.966901
# Currently retrieving data for India: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:33.545270
# Currently retrieving data for India: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:35.193167
# Currently retrieving data for India: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.583901
# Currently retrieving data for India: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:38.452747
# Currently retrieving data for India: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:39.832613
# Currently retrieving data for India: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:41.498936
# Currently retrieving data for India: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:42.921508
# Currently retrieving data for India: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:44.311876
# Currently retrieving data for India: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:45.683286
# Currently retrieving data for India: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:47.226192
# Currently retrieving data for India: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:48.897479
# Currently retrieving data for India: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:50.395979
# Currently retrieving data for India: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:51.873548
# Currently retrieving data for India: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.246353
# Currently retrieving data for India: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:54.520667
# Currently retrieving data for India: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.782288
# Currently retrieving data for India: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:57.392362
# Currently retrieving data for India: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:58.948778
# Currently retrieving data for India: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.189839
# Currently retrieving data for India: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:01.780215
# Currently retrieving data for India: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:03.361149
# Currently retrieving data for India: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:04.916521
# Currently retrieving data for India: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.231094
# Currently retrieving data for India: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:08.273066
# Currently retrieving data for India: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:09.765860
# Currently retrieving data for India: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:11.303102
# Currently retrieving data for India: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:13.121117
# Currently retrieving data for India: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.546780
# Currently retrieving data for India: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:15.885692
# Currently retrieving data for India: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:17.171565
# Currently retrieving data for India: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:18.731497
# Currently retrieving data for India: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:19.921168
# Currently retrieving data for India: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:21.346307
# Currently retrieving data for India: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:22.764251
# Currently retrieving data for India: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:24.279607
# Currently retrieving data for India: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:25.938291
# Currently retrieving data for India: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.257656
# Currently retrieving data for India: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:28.741357
# Currently retrieving data for India: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:30.268234
# Currently retrieving data for India: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:31.703138
# Currently retrieving data for India: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:33.099375
# Currently retrieving data for India: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:34.499604
# Currently retrieving data for India: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:36.053770
# Currently retrieving data for India: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:37.393449
# Currently retrieving data for India: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:38.868033
# Currently retrieving data for India: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:40.482969
# Currently retrieving data for India: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:41.777380
# Currently retrieving data for India: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:43.069077
# Currently retrieving data for India: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.575160
# Currently retrieving data for India: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:45.899085
# Currently retrieving data for India: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:47.307021
# Currently retrieving data for India: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:48.913215
# Currently retrieving data for India: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:50.398268
# Currently retrieving data for India: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:51.935799
# Currently retrieving data for India: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:53.233571
# Currently retrieving data for India: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:54.497038
# Currently retrieving data for India: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:56.027101
# Currently retrieving data for India: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:57.676442
# Currently retrieving data for India: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:59.359370
# Currently retrieving data for India: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:00.649130
# Currently retrieving data for India: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:02.222470
# Currently retrieving data for India: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:03.757767
# Currently retrieving data for India: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:05.236693
# Currently retrieving data for India: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:07.135422
# Currently retrieving data for India: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:08.526688
# Currently retrieving data for India: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:10.009726
# Currently retrieving data for India: from 2022-01-01 to 2022-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:11.379204
# Currently retrieving data for India: from 2022-02-01 to 2022-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:12.616242
# Currently retrieving data for India: from 2022-03-01 to 2022-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:13.976329
# Currently retrieving data for India: from 2022-04-01 to 2022-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:15.218966
# Currently retrieving data for India: from 2022-05-01 to 2022-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:16.945554
# Currently retrieving data for India: from 2022-06-01 to 2022-06-25
# Time elapsed (hh:mm:ss.ms) 0:02:18.013183
#
#
# export India completed!
